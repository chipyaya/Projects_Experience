# %%
import pandas as pd

# %%
def read_file(path):
    data = pd.read_csv(path)
    s = set([(i,j) for i,j in zip(list(data['User-ID']),list(data['ISBN']))])
    print(len(data), len(s))
    return data,s

implicit, s_impli = read_file('data/implicit_ratings.csv')
train, s_train = read_file('data/book_ratings_train.csv')
test, s_test = read_file('data/book_ratings_test.csv')
books = pd.read_csv('data/books.csv')
users = pd.read_csv('data/users.csv')
# Out:
# 716109 716109
# 260202 260202
# 173469 173469

# %%
print(len(set(list(train['User-ID'].unique())+list(test['User-ID'].unique()))) + len(set(list(train['ISBN'].unique())+list(test['ISBN'].unique()))))
# Out:
# 263778

# %%
77805+ 185816
# Out:
# 263621

# %%
#books['Book-Title'].fillna('', inplace=True)
books['Book-Title'].apply(lambda s: len(s))
# Out:
# 0          19
# 1          12
# 2          20
# 3          98
# 4          22
# 5          22
# 6          79
# 7          15
# 8          75
# 9          39
# 10         27
# 11         74
# 12         18
# 13          8
# 14         77
# 15         44
# 16         55
# 17         29
# 18         13
# 19         36
# 20         93
# 21         61
# 22        122
# 23         70
# 24         28
# 25         24
# 26         11
# 27          8
# 28          8
# 29         24
#          ...
# 271349     61
# 271350     60
# 271351     52
# 271352     35
# 271353     44
# 271354     51
# 271355     58
# 271356     74
# 271357     71
# 271358     28
# 271359      5
# 271360     58
# 271361     34
# 271362     88
# 271363     39
# 271364     43
# 271365     10
# 271366     11
# 271367     29
# 271368     55
# 271369     88
# 271370     62
# 271371     17
# 271372     17
# 271373     45
# 271374     26
# 271375     23
# 271376     61
# 271377     27
# 271378    126
# ...

# %%
books['Book-Description'].fillna('', inplace=True)
books['Book-Description'].apply(lambda s: len(s))
# Out:
# 0         2123
# 1         2847
# 2          118
# 3         1084
# 4         1426
# 5          699
# 6         1526
# 7         1128
# 8          411
# 9          571
# 10         786
# 11        1245
# 12         940
# 13           0
# 14         511
# 15        1053
# 16           0
# 17           0
# 18         918
# 19         729
# 20         418
# 21         433
# 22        1581
# 23         454
# 24         248
# 25           0
# 26         784
# 27         571
# 28         656
# 29         531
#           ...
# 271349       0
# 271350       0
# 271351      21
# 271352       0
# 271353       0
# 271354       0
# 271355       0
# 271356    1099
# 271357       0
# 271358       0
# 271359       0
# 271360     131
# 271361       0
# 271362    1796
# 271363       0
# 271364     293
# 271365       0
# 271366       0
# 271367     593
# 271368     885
# 271369       0
# 271370    1240
# 271371      12
# 271372     651
# 271373     329
# 271374     158
# 271375       0
# ...

# %%
print(len(s_train | s_impli | s_test) == len(s_train)+len(s_impli)+len(s_test))
# Out:
# True

# %%
print(len(s_train & s_impli))
print(len(s_test & s_impli))
print(len(s_train & s_test))
# Out:
# 0
# 0
# 0

# %%
data = pd.read_csv('data/users.csv')
len(set(data['Location'].apply(lambda x: x.split(',')[2])))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-040fc8fc10a1> in <module>()
#       1 data = pd.read_csv('data/users.csv')
# ----> 2 len(set(data['Location'].apply(lambda x: x.split(',')[2] )))
#
# /nfs/Sif/chipcheng/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66645)()
#
# <ipython-input-38-040fc8fc10a1> in <lambda>(x)
#       1 data = pd.read_csv('data/users.csv')
# ----> 2 len(set(data['Location'].apply(lambda x: x.split(',')[2] )))
#
# IndexError: list index out of range

# %%
list(set(data['Location'].apply(lambda x: x.split(', ')[-1])))
# Out:
# ['taiwan',
#  'rice',
#  'bih',
#  'cambodia',
#  'brazil',
#  'catalunya(catalonia)',
#  'baxter',
#  'san salvador,',
#  'fiji',
#  'israel"',
#  'r.o.c.',
#  'turkey',
#  'rio de jianero,',
#  'lancashire,',
#  'brunei darussalam',
#  'hainaut,',
#  'waikato,',
#  'havana,',
#  'in',
#  'korea',
#  'uusa',
#  'overijssel,',
#  'zuidholland,',
#  'macedonia',
#  'hidalgo',
#  'buncombe',
#  'sabah,',
#  'morogoro,',
#  'oberösterreich,',
#  'fort bend',
#  'u.k.',
#  'iran"',
#  'minho,',
#  'kiribati',
#  'east sussex,',
#  'na,',
#  'u k',
#  'ile de france,',
#  'gotland,',
#  'virguinia,',
#  'ust',
#  'the world tomorrow',
#  'rheinland-pfalz,',
#  'china,',
#  'west indies,',
#  'philippine',
#  'avon,',
#  'guinea',
#  'morgan',
#  'serbia,',
#  'puglia,',
#  'new brunswick,',
#  'catalunya',
#  'guatemala"',
#  'galiza neghra',
#  'wa.,',
#  'basilicata',
#  'chile"',
#  'scotland,',
#  'vorce',
#  'houston',
#  'catalunya spain',
#  'guam',
#  'rapides',
#  'galiza',
# ...

# %%
import numpy as np
print(len(data) - sum(data['Age'].isnull()), (len(data) - sum(data['Age'].isnull())) / len(data))
# Out:
# 168096 0.6028014258152895

# %%
len(data)
# Out:
# 278858

# %%
data['Age']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-572ee1be21fb> in <module>()
# ----> 1 data['Age']
#
# NameError: name 'data' is not defined

# %%
books = pd.read_csv('data/books.csv')
print(len(set(books['Book-Author'])), len(set(books['Book-Author'])) / len(books))

# %%
books.groupby('Book-Author').transform('count')
# Out:
#         ISBN  Book-Title  Year-Of-Publication  Publisher  Image-URL-S  \
# 0          2           2                    2          2            2
# 1          2           2                    2          2            2
# 2          3           3                    3          3            3
# 3          2           2                    2          2            2
# 4          1           1                    1          1            1
# 5         49          49                   49         49           49
# 6          5           5                    5          5            5
# 7         37          37                   37         37           37
# 8          3           3                    3          3            3
# 9         24          24                   24         24           24
# 10         6           6                    6          6            6
# 11         2           2                    2          2            2
# ...

# %%
len(books[books['Book-Author'] == books['Book-Author'][18]])
# Out:
# 138

# %%
books.groupby('Year-Of-Publication').transform('count')
# Out:
#          ISBN  Book-Title  Book-Author  Publisher  Image-URL-S  Image-URL-M  \
# 0       17628       17628        17628      17627        17628        17628
# 1       17360       17360        17360      17359        17360        17360
# 2        9389        9389         9389       9389         9389         9389
# 3       17432       17432        17432      17432        17432        17432
# 4       17432       17432        17432      17432        17432        17432
# 5        9389        9389         9389       9389         9389         9389
# 6       17235       17235        17235      17235        17235        17235
# 7       10602       10602        10602      10602        10602        10602
# 8       14031       14031        14031      14031        14031        14031
# 9       17628       17628        17628      17627        17628        17628
# 10       7493        7493         7493       7493         7493         7493
# ...

# %%
a = list(set(books['Year-Of-Publication']))
a.sort()
a
# Out:
# [0,
#  1376,
#  1378,
#  1806,
#  1897,
#  1900,
#  1901,
#  1902,
#  1904,
#  1906,
#  1908,
#  1909,
#  1910,
#  1911,
#  1914,
#  1917,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2008,
#  2010,
#  2011,
#  2012,
#  2020,
#  2021,
#  2024,
# ...

# %%
books[books['Year-Of-Publication'] == 2050]
# Out:
#              ISBN                                         Book-Title  \
# 80267  0140301690  Alice's Adventures in Wonderland and Through t...
# 97830  0140201092      Outline of European Architecture (Pelican S.)
#
#             Book-Author  Year-Of-Publication     Publisher  \
# 80267     Lewis Carroll                 2050  Puffin Books
# 97830  Nikolaus Pevsner                 2050   Penguin USA
#
#                                              Image-URL-S  \
# 80267  http://images.amazon.com/images/P/0140301690.0...
# 97830  http://images.amazon.com/images/P/0140201092.0...
#
#                                              Image-URL-M  \
# 80267  http://images.amazon.com/images/P/0140301690.0...
# 97830  http://images.amazon.com/images/P/0140201092.0...
#
#                                              Image-URL-L  \
# 80267  http://images.amazon.com/images/P/0140301690.0...
# 97830  http://images.amazon.com/images/P/0140201092.0...
#
# ...

# %%
books.groupby('Year-Of-Publication').transform('count')
# Out:
#          ISBN  Book-Title  Book-Author  Publisher  Image-URL-S  Image-URL-M  \
# 0       17628       17628        17628      17627        17628        17628
# 1       17360       17360        17360      17359        17360        17360
# 2        9389        9389         9389       9389         9389         9389
# 3       17432       17432        17432      17432        17432        17432
# 4       17432       17432        17432      17432        17432        17432
# 5        9389        9389         9389       9389         9389         9389
# 6       17235       17235        17235      17235        17235        17235
# 7       10602       10602        10602      10602        10602        10602
# 8       14031       14031        14031      14031        14031        14031
# 9       17628       17628        17628      17627        17628        17628
# 10       7493        7493         7493       7493         7493         7493
# ...
